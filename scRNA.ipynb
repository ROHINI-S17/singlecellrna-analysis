# %% [markdown]
# <a href="https://colab.research.google.com/github/ROHINI-S17/singlecellrna-analysis/blob/main/scRNA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scanpy anndata matplotlib seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 37.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.6/168.6 kB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 17.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 89.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.7/53.7 kB 3.5 MB/s eta 0:00:00
# ...

# %%
import scanpy as sc
adata = sc.read_h5ad("/content/drive/MyDrive/98d09c1a-33d5-462a-8ec9-9693253ec649.h5ad")
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 1387 × 32031
# ...

# %%
print(adata.var_names[:50])
# Out:
# Index(['ENSDARG00000000001', 'ENSDARG00000000002', 'ENSDARG00000000018',
#        'ENSDARG00000000019', 'ENSDARG00000000068', 'ENSDARG00000000069',
#        'ENSDARG00000000086', 'ENSDARG00000000103', 'ENSDARG00000000142',
#        'ENSDARG00000000151', 'ENSDARG00000000161', 'ENSDARG00000000175',
#        'ENSDARG00000000183', 'ENSDARG00000000189', 'ENSDARG00000000212',
#        'ENSDARG00000000229', 'ENSDARG00000000241', 'ENSDARG00000000324',
#        'ENSDARG00000000349', 'ENSDARG00000000369', 'ENSDARG00000000370',
#        'ENSDARG00000000380', 'ENSDARG00000000394', 'ENSDARG00000000423',
#        'ENSDARG00000000442', 'ENSDARG00000000460', 'ENSDARG00000000472',
#        'ENSDARG00000000474', 'ENSDARG00000000476', 'ENSDARG00000000489',
#        'ENSDARG00000000503', 'ENSDARG00000000516', 'ENSDARG00000000529',
#        'ENSDARG00000000540', 'ENSDARG00000000542', 'ENSDARG00000000551',
#        'ENSDARG00000000563', 'ENSDARG00000000567', 'ENSDARG00000000568',
# ...

# %%
print(adata.var.columns)
# Out:
# Index(['gene_short_name', 'chromosome', 'bp1', 'bp2', 'gene_strand',
#        'num_cells_expressed', 'feature_is_filtered', 'feature_name',
#        'feature_reference', 'feature_biotype', 'feature_length',
#        'feature_type'],
#       dtype='object')

# %%
print(adata.var.head())
# Out:
#                    gene_short_name chromosome       bp1       bp2 gene_strand  \
# id
# ENSDARG00000000001         slc35a5          9  34111567  34121839           -
# ENSDARG00000000002          ccdc80          9  34089156  34113709           +
# ENSDARG00000000018            nrf1          4  15080885  15103696           -
# ENSDARG00000000019           ube2h          4  15011341  15060376           +
# ENSDARG00000000068       slc9a3r1a         12  33484458  33537626           +
#
#                    num_cells_expressed  feature_is_filtered feature_name  \
# id
# ENSDARG00000000001                conf                False      slc35a5
# ENSDARG00000000002                conf                False       ccdc80
# ENSDARG00000000018                conf                False         nrf1
# ENSDARG00000000019                conf                False        ube2h
# ENSDARG00000000068                conf                False      nherf1a
#
# ...

# %%
print(adata.var['chromosome'].head(50))
# Out:
# id
# ENSDARG00000000001     9
# ENSDARG00000000002     9
# ENSDARG00000000018     4
# ENSDARG00000000019     4
# ENSDARG00000000068    12
# ENSDARG00000000069    24
# ENSDARG00000000086     1
# ENSDARG00000000103     6
# ENSDARG00000000142    10
# ENSDARG00000000151     3
# ENSDARG00000000161    20
# ENSDARG00000000175     3
# ENSDARG00000000183    22
# ENSDARG00000000189    16
# ENSDARG00000000212    22
# ENSDARG00000000229    22
# ENSDARG00000000241     9
# ENSDARG00000000324     2
# ENSDARG00000000349    21
# ENSDARG00000000369     9
# ENSDARG00000000370    16
# ENSDARG00000000380    14
# ENSDARG00000000394    14
# ENSDARG00000000423     7
# ENSDARG00000000442     7
# ENSDARG00000000460     7
# ENSDARG00000000472    11
# ENSDARG00000000474    23
# ENSDARG00000000476     9
# ENSDARG00000000489    14
# ENSDARG00000000503    19
# ENSDARG00000000516     9
# ENSDARG00000000529     9
# ENSDARG00000000540     9
# ENSDARG00000000542     9
# ENSDARG00000000551    13
# ...

# %%
print(adata.obs.columns)
print(f"Cells: {adata.n_obs}, Genes: {adata.n_vars}")
sc.pl.umap(adata, color='cell_type')
# Out:
# Index(['Size_Factor', 'n.umi', 'perc_mitochondrial_umis', 'hash_umis',
#        'log.n.umi', 'top_to_second_best_ratio', 'projection_group',
#        'cell_type_long', 'cell_type_broad', 'num_genes_expressed', 'embryo_ID',
#        'perturbation', 'target', 'type', 'strain', 'expt', 'cross_batch',
#        'collection_batch', 'dis_protocol', 'fix_protocol', 'timepoint',
#        'cold_delay', 'subumap3d_1', 'subumap3d_2', 'subumap3d_3',
#        'mean_nn_time', 'cells_per_embryo', 'cell_type_ontology_term_id',
#        'donor_id', 'tissue_type', 'cell_line_ontology_term_id',
#        'perturbation_strategy', 'perturbation_role',
#        'perturbation_target_gene_id', 'perturbation_id', 'is_primary_data',
#        'development_stage_ontology_term_id', 'sex_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id', 'disease_ontology_term_id',
#        'tissue_ontology_term_id', 'assay_ontology_term_id', 'suspension_type',
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
order = adata.obs['cell_type'].value_counts().index
sns.countplot(y=adata.obs['cell_type'], order=order)
plt.title("Cell Type Distribution")
plt.xlabel("Cell Count")
plt.ylabel("Cell Type")
plt.show()

# %%
print(adata.var.columns)
# Out:
# Index(['gene_short_name', 'chromosome', 'bp1', 'bp2', 'gene_strand',
#        'num_cells_expressed', 'feature_is_filtered', 'feature_name',
#        'feature_reference', 'feature_biotype', 'feature_length',
#        'feature_type'],
#       dtype='object')

# %%
print(adata.obs['cell_type'].unique())
# Out:
# ['pancreatic D cell', 'unknown', 'pancreatic endocrine cell', 'pancreatic A cell', 'type B pancreatic cell']
# Categories (5, object): ['type B pancreatic cell', 'pancreatic A cell', 'pancreatic D cell',
#                          'pancreatic endocrine cell', 'unknown']

# %%
print(adata.obs.columns)
print(f"Cells: {adata.n_obs}, Genes: {adata.n_vars}")
sc.pl.umap(adata, color='cell_type')
# Out:
# Index(['Size_Factor', 'n.umi', 'perc_mitochondrial_umis', 'hash_umis',
#        'log.n.umi', 'top_to_second_best_ratio', 'projection_group',
#        'cell_type_long', 'cell_type_broad', 'num_genes_expressed', 'embryo_ID',
#        'perturbation', 'target', 'type', 'strain', 'expt', 'cross_batch',
#        'collection_batch', 'dis_protocol', 'fix_protocol', 'timepoint',
#        'cold_delay', 'subumap3d_1', 'subumap3d_2', 'subumap3d_3',
#        'mean_nn_time', 'cells_per_embryo', 'cell_type_ontology_term_id',
#        'donor_id', 'tissue_type', 'cell_line_ontology_term_id',
#        'perturbation_strategy', 'perturbation_role',
#        'perturbation_target_gene_id', 'perturbation_id', 'is_primary_data',
#        'development_stage_ontology_term_id', 'sex_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id', 'disease_ontology_term_id',
#        'tissue_ontology_term_id', 'assay_ontology_term_id', 'suspension_type',
# ...

# %%
import scanpy as sc
import matplotlib.pyplot as plt
adata = sc.read_h5ad("/content/drive/MyDrive/98d09c1a-33d5-462a-8ec9-9693253ec649.h5ad")
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
sc.tl.rank_genes_groups(adata, groupby='cell_type', method='wilcoxon')
sc.pl.rank_genes_groups(adata, n_genes=5, sharey=False)

# %%
sc.pl.rank_genes_groups_heatmap(adata, n_genes=5, groupby='cell_type', show_gene_labels=True)
